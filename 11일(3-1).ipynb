# %%
my_key='GsACnsPniN6nEyKT%2BZ4mzx8suMwolIcpZpoif9KzPO%2BrIIgLhlhF7U3HUv%2BzaEndRhofIlcMc3%2BYcf063RvHIg%3D%3D'

# %%
url1='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey='
url2='LAWD_CD=11110&DEAL_YMD=201512&'
url=url1+my_key+url2

# %%
url
# Out:
# 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=GsACnsPniN6nEyKT%2BZ4mzx8suMwolIcpZpoif9KzPO%2BrIIgLhlhF7U3HUv%2BzaEndRhofIlcMc3%2BYcf063RvHIg%3D%3DLAWD_CD=11110&DEAL_YMD=201512&'

# %%
url2='&type=xml'

# %%
http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=GsACnsPniN6nEyKT%2BZ4mzx8suMwolIcpZpoif9KzPO%2BrIIgLhlhF7U3HUv%2BzaEndRhofIlcMc3%2BYcf063RvHIg%3D%3DLAWD_CD=11110&DEAL_YMD=201512&

# %%
import requests

lawd_cd='11110'
deal_ymd='201512'
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
params='serviceKey=%s&LAWD_CD=%s&DEAL_YMD=%s'%(key,lawd_cd,deal_ymd)
url3='&type=json'
url=base_url+params+url3
print(url)
key='s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D'
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %%
import urllib.request
res=urllib.request.urlopen(url)
res

# %%
xml_str=res.read().decode('utf-8')
xml_str
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>120,000</거래금액><건물면적>395</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>2001</건축년도><년>2015</년><대지면적>160.64</대지면적><법정동> 효자동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>31</일><지역코드>11110</지역코드></item><item><거래금액>483,000</거래금액><건물면적>937</건물면적><건물주용도>제2종근린생활</건물주용도><건축년도>1990</건축년도><년>2015</년><대지면적>503.5</대지면적><법정동> 체부동</법정동><시군구>종로구</시군구><용도지역>제2종일반주거</용도지역><월>12</월><유형>일반</유형><일>15</일><지역코드>11110</지역코드></item><item><거래금액>22,000</거래금액><건물면적>31</건물면적><건물주용도>판매</건물주용도><건축년도>2007</건축년도><년>2015</년><대지면적> </대지면적><법정동> 종로1가</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>집합</유형><일>10</일><지역코드>11110</지역코드><층>-1</층></item><item><거래금액>158,000</거래금액><건물면적>276</건물면적><건물주용도>숙박</건물주용도><건축년도>1959</건축년도><년>2015</년><대지면적>72.8</대지면적><법정동> 와룡동</법정동><시군구>종로구</시군구><용도지역>일반상업</용도지역><월>12</월><유형>일반</유형><일>8</일><지역코드>11110</지역코드></ite
# ...

# %%
xml_str.find_all('item')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-ffa2ef546d8c> in <module>
# ----> 1 xml_str.find_all('item')
#
# AttributeError: 'str' object has no attribute 'find_all'

# %%
url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_=201512&type=json'
aa='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json'
aa==url
# Out:
# False

# %%
for i ,check in enumerate(aa):
    if check!=url[i]:
        print(i)
        print(aa[i-5:i+5])
        print(url[i-5:i+5])
# Out:
# 224
# DEAL_YMD=2
# DEAL_=2015
# 225
# EAL_YMD=20
# EAL_=20151
# 226
# AL_YMD=201
# AL_=201512
# 227
# L_YMD=2015
# L_=201512&
# 228
# _YMD=20151
# _=201512&t
# 229
# YMD=201512
# =201512&ty
# 230
# MD=201512&
# 201512&typ
# 231
# D=201512&t
# 01512&type
# 232
# =201512&ty
# 1512&type=
# 233
# 201512&typ
# 512&type=j
# 234
# 01512&type
# 12&type=js
# 235
# 1512&type=
# 2&type=jso
# 236
# 512&type=j
# &type=json
# 237
# 12&type=js
# type=json
# 238
# 2&type=jso
# ype=json
# 239
# &type=json
# pe=json
# 240
# type=json
# e=json
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-9c66d6284ce0> in <module>
#       1 for i ,check in enumerate(aa):
# ----> 2     if check!=url[i]:
#       3         print(i)
#       4         print(aa[i-5:i+5])
#       5         print(url[i-5:i+5])
#
# IndexError: string index out of range

# %%
import requests

lawd_cd='11110'
deal_ymd='201512'
my_key_decode=requests.utils.unquote(key)
base_url='http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?'
req_params={'serviceKey':my_key_decode,
            'LAWD_CD':lawd_cd,'DEAL_YMD':deal_ymd,'type':'json'}

# %%
r=requests.get(base_url,params=req_params)
print(r.url)
# Out:
# http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcNrgTrade?serviceKey=s1JerABCGMtqqLUB0r7byT8n7uzwvD9lPsxSfKp9ID5seIFNMkOQzIsACpahzhcUznSQXlirur4Ivp38W2Zd3Q%3D%3D&LAWD_CD=11110&DEAL_YMD=201512&type=json

# %%
#xml--> json 변환
res=urllib.request.urlopen(r.url)
res
xml_str=res.read().decode('utf-8')
xml_str
import xmltodict
import json

# %%
json_str=json.dumps(xmltodict.parse(xml_str),indent=4,ensure_ascii=False)

json_object=json.loads(json_str)
json_object
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '120,000',
#       '건물면적': '395',
#       '건물주용도': '제2종근린생활',
#       '건축년도': '2001',
#       '년': '2015',
#       '대지면적': '160.64',
#       '법정동': '효자동',
#       '시군구': '종로구',
#       '용도지역': '제2종일반주거',
#       '월': '12',
#       '유형': '일반',
#       '일': '31',
#       '지역코드': '11110'},
#      {'거래금액': '483,000',
#       '건물면적': '937',
#       '건물주용도': '제2종근린생활',
#       '건축년도': '1990',
#       '년': '2015',
#       '대지면적': '503.5',
#       '법정동': '체부동',
#       '시군구': '종로구',
#       '용도지역': '제2종일반주거',
#       '월': '12',
#       '유형': '일반',
#       '일': '15',
#       '지역코드': '11110'},
#      {'거래금액': '22,000',
#       '건물면적': '31',
#       '건물주용도': '판매',
#       '건축년도': '2007',
#       '년': '2015',
#       '대지면적': None,
#       '법정동': '종로1가',
#       '시군구': '종로구',
#       '용도지역': '일반상업',
#       '월': '12',
#       '유형': '집합',
#       '일': '10',
# ...

# %%
json_object['response']['body']['items']
# Out:
# {'item': [{'거래금액': '120,000',
#    '건물면적': '395',
#    '건물주용도': '제2종근린생활',
#    '건축년도': '2001',
#    '년': '2015',
#    '대지면적': '160.64',
#    '법정동': '효자동',
#    '시군구': '종로구',
#    '용도지역': '제2종일반주거',
#    '월': '12',
#    '유형': '일반',
#    '일': '31',
#    '지역코드': '11110'},
#   {'거래금액': '483,000',
#    '건물면적': '937',
#    '건물주용도': '제2종근린생활',
#    '건축년도': '1990',
#    '년': '2015',
#    '대지면적': '503.5',
#    '법정동': '체부동',
#    '시군구': '종로구',
#    '용도지역': '제2종일반주거',
#    '월': '12',
#    '유형': '일반',
#    '일': '15',
#    '지역코드': '11110'},
#   {'거래금액': '22,000',
#    '건물면적': '31',
#    '건물주용도': '판매',
#    '건축년도': '2007',
#    '년': '2015',
#    '대지면적': None,
#    '법정동': '종로1가',
#    '시군구': '종로구',
#    '용도지역': '일반상업',
#    '월': '12',
#    '유형': '집합',
#    '일': '10',
#    '지역코드': '11110',
#    '층': '-1'},
#   {'거래금액': '158,000',
#    '건물면적': '276',
#    '건물주용도': '숙박',
#    '건축년도': '1959',
#    '년': '2015',
#    '대지면적': '72.8',
#    '법정동': '와룡동',
#    '시군구': '종로구',
#    '용도지역': '일반상업',
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize
df=json_normalize(json_object['response']['body']['items']['item'])
df.head(3)
# Out:
# <ipython-input-101-7c55c18762b9>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df=json_normalize(json_object['response']['body']['items']['item'])
#       거래금액 건물면적    건물주용도  건축년도     년    대지면적   법정동  시군구     용도지역   월  유형   일  \
# 0  120,000  395  제2종근린생활  2001  2015  160.64   효자동  종로구  제2종일반주거  12  일반  31
# 1  483,000  937  제2종근린생활  1990  2015   503.5   체부동  종로구  제2종일반주거  12  일반  15
# 2   22,000   31       판매  2007  2015    None  종로1가  종로구     일반상업  12  집합  10
#
#     지역코드    층
# 0  11110  NaN
# 1  11110  NaN
# 2  11110   -1

# %%
#https://docs.python.rg/ko/3/library/json.html
#json(JavaScrip Object Notation)

# %%
#파이썬 데이터--> json 데이터
json.dumps(data)
json.dumps

# %%
import json
dic_data={'이름':'김인공',
         '나이':29,
         '거주지':'서울',
         '신체정보':{'키':165,'몸무게':65.2}
         ,'취미':['컴퓨터','파이썬','데이터덕후']}
type(dic_data)
# Out:
# dict

# %%
json_data=json.dumps(dic_data)
type(json_data)
# Out:
# str

# %%
print(json_data)
# Out:
# {"\uc774\ub984": "\uae40\uc778\uacf5", "\ub098\uc774": 29, "\uac70\uc8fc\uc9c0": "\uc11c\uc6b8", "\uc2e0\uccb4\uc815\ubcf4": {"\ud0a4": 165, "\ubab8\ubb34\uac8c": 65.2}, "\ucde8\ubbf8": ["\ucef4\ud4e8\ud130", "\ud30c\uc774\uc36c", "\ub370\uc774\ud130\ub355\ud6c4"]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-cc03d23a7e78> in <module>
# ----> 1 print(json_data).decode('utf-8')
#
# AttributeError: 'NoneType' object has no attribute 'decode'

# %%
json_data=json.dumps(dic_data,indent=3,sort_keys=True,ensure_ascii=False)#indent 몇개띄어쓰기
print(json_data)
# Out:
# {
#    "거주지": "서울",
#    "나이": 29,
#    "신체정보": {
#       "몸무게": 65.2,
#       "키": 165
#    },
#    "이름": "김인공",
#    "취미": [
#       "컴퓨터",
#       "파이썬",
#       "데이터덕후"
#    ]
# }

# %%
#파이썬 불러오기
json_dic=json.loads(json_data)
type(json_dic)
# Out:
# dict

# %%
#딕셔너리
json_dic['신체정보']['키']
# Out:
# 165

# %%
json_dic['취미'][1]
# Out:
# '파이썬'

# %%
json_data.strip('\n')
# Out:
# '{\n   "거주지": "서울",\n   "나이": 29,\n   "신체정보": {\n      "몸무게": 65.2,\n      "키": 165\n   },\n   "이름": "김인공",\n   "취미": [\n      "컴퓨터",\n      "파이썬",\n      "데이터덕후"\n   ]\n}'

# %%
json_data[1]
# Out:
# '\n'

# %%
#주민등록 뒷자리(7자리) ***로 만들어 출력(split,for,if처리)

# %%
data="""
park 800905-1049118
kim 700905-1059119
jang 920625-2049307
"""
data
# Out:
# '\npark 800905-1049118\nkim 700905-1059119\njang 920625-2049307\n'

# %%
data.strip("\n")
# Out:
# 'park 800905-1049118\nkim 700905-1059119\njang 920625-2049307'

# %%
data.split('\n')
# Out:
# ['', 'park 800905-1049118', 'kim 700905-1059119', 'jang 920625-2049307', '']

# %%
data1=data.split()
data1
# Out:
# ['park', '800905-1049118', 'kim', '700905-1059119', 'jang', '920625-2049307']

# %%
data1[1],data1[3],data1[5]
# Out:
# ('800905-1049118', '700905-1059119', '920625-2049307')

# %%
m=data1[1].split('-')
m
# Out:
# ['800905', '1049118']

# %%
for i, check in enumerate(data1):
    k=2*i+1
    m=data1[k].split('-')[1]="*******"
    solve=data1[k].split('-')[0]+m
    print(data1[k].split('-')[0]+'-'+m)
# Out:
# 800905-*******
# 700905-*******
# 920625-*******
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-274-6e10b30379d4> in <module>
#       1 for i, check in enumerate(data1):
#       2     k=2*i+1
# ----> 3     m=data1[k].split('-')[1]="*******"
#       4     solve=data1[k].split('-')[0]+m
#       5     print(data1[k].split('-')[0]+'-'+m)
#
# IndexError: list index out of range

# %%
for i, check in enumerate(data1):
    k=2*i+1
    m=data1[k].split('-')[1]="*******"
    solve=data1[k].split('-')[0]+m
    try:
        print(data1[k].split('-')[0]+'-'+m)
    except:
        print("예외")
# Out:
# 800905-*******
# 700905-*******
# 920625-*******
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-277-dafc3620126b> in <module>
#       1 for i, check in enumerate(data1):
#       2     k=2*i+1
# ----> 3     m=data1[k].split('-')[1]="*******"
#       4     solve=data1[k].split('-')[0]+m
#       5     try:
#
# IndexError: list index out of range

# %%
data="""
park 800905-1049118
kim 700905-1059119
jang 920625-2049307
"""
data
# Out:
# '\npark 800905-1049118\nkim 700905-1059119\njang 920625-2049307\n'

# %%
result=[]
for line in data.split('\n'):
    word_result=[]
    for word in line.split():
        print(word)
        if len(word)==14 and word[:6].isdigit() and word[7:].isdigit():
            word=word[:6]+'-'+"*******"
        word_result.append(word)
        result.append(''.join(word_result))
print("\n".join(result))
# Out:
# park
# 800905-1049118
# kim
# 700905-1059119
# jang
# 920625-2049307
# park
# park800905-*******
# kim
# kim700905-*******
# jang
# jang920625-*******

# %%
result=[]
for word in data.split():
    word=word[:6]+'-'+"*******"
    print(word)
    result.append(word)
# Out:
# park-*******
# 800905-*******
# kim-*******
# 700905-*******
# jang-*******
# 920625-*******

# %%
import re
pat=re.compile('(\d{6})[-]\d{7}')
pat
# Out:
# re.compile(r'(\d{6})[-]\d{7}', re.UNICODE)

# %%
result1=pat.sub("\g<1>-*******",data)
result1
# Out:
# '\npark 800905-*******\nkim 700905-*******\njang 920625-*******\n'
