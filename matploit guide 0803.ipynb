# %%
#https://matplotlib.org/3.3.0/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax=plt.subplots()
x=[1,2,3,4]
y=[1,4,2,3]
ax.plot(x,y)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'go--',linewidth=5,markersize=10)

# %%
x1=x; y2=y
x2=[4,6,8]; y2=[10,20,10]
plt.plot(x,y,'r^',x2,y2,'g--')
# Out:
# [<matplotlib.lines.Line2D at 0x2b0a296cd60>,
#  <matplotlib.lines.Line2D at 0x2b0a296cd90>]

# %%
import pandas as pd
a=pd.DataFrame(np.random.rand(4,5),columns=list('abcde'))
a_asarray=a.values
a
# Out:
#           a         b         c         d         e
# 0  0.897453  0.636132  0.142442  0.540079  0.129929
# 1  0.846096  0.962455  0.905957  0.224600  0.594321
# 2  0.339834  0.492855  0.948393  0.238279  0.914265
# 3  0.571341  0.389454  0.969299  0.299038  0.539497

# %%
a_asarray
# Out:
# array([[0.76962305, 0.77722928, 0.67552112, 0.18185075, 0.51509277],
#        [0.09015178, 0.41292959, 0.12516088, 0.86547107, 0.13665801],
#        [0.68979776, 0.77821349, 0.01241905, 0.3718183 , 0.98848178],
#        [0.46202925, 0.53082532, 0.23103438, 0.52865255, 0.78325217]])

# %%
x=np.linspace(0,2,100)
fig,ax=plt.subplots()
ax.plot(x,x,label='linear')
ax.plot(x,x**2,label='quadratic')
ax.plot(x,x**3,label='cubic')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.legend()

# %%
x=np.linspace(0,2,100)

plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.legend()

# %%
def my_plotter(ax,data1,data2,param_dict):
    out=ax.plot(data1,data2,**param_dict)
    return out

# %%
data1,data2,data3,data4=np.random.randn(4,100)
fig,ax=plt.subplots(1,1)
my_plotter(ax,data1,data2,{'marker':'x'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-30931510dfec> in <module>
#       1 data1,data2,data3,data4=np.random.randn(4,100)
#       2 fig,ax=plt.subplots(1,1)
# ----> 3 my_plotter(ax,data1,data2,{'marker':'x'})
#
# <ipython-input-135-95ad2aae75f7> in my_plotter(ax, data1, data2, param_dict)
#       1 def my_plotter(ax,data1,data2,param_dict):
# ----> 2     out=ax[0][0].plot(data1,**param_dict)
#       3     out=ax[1][0].plot(data2,**param_dict)
#       4     return out
#       5
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
#subplots(1,2) 일때
fig,(ax1,ax2)=plt.subplots(1,2)
my_plotter(ax1,data1,data2,{'marker':'x'})
my_plotter(ax2,data1,data2,{'marker':'o'})

# %%
def my_plotter(ax,data1,data2,param_dict):
    out=ax[0].plot(data1,**param_dict)
    out=ax[1].plot(data2,**param_dict)
    return out

data1,data2=np.random.randn(2,100)
fig,ax=plt.subplots(2)
my_plotter(ax,data1,data2,{'marker':'x'})

# %%
def my_plotter(ax,data1,data2,param_dict):
    out=ax[0][0].plot(data1,**param_dict)
    out=ax[1][0].plot(data2,**param_dict)
    return out

data1,data2=np.random.randn(2,100)
fig,ax=plt.subplots(2,2)
my_plotter(ax,data1,data2,{'marker':'x'})
